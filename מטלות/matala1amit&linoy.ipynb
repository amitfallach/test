# %% [markdown]
# ---
# ### name of students:
#
# עמית פלאח תז 318510070
#
# לינוי מדלזי תז 206073124

# %% [markdown]
# open folder panda

# %%
import pandas as pd

# %% [markdown]
# save and open csv file

# %%
fileO = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
covidata = pd.read_csv(fileO)

# %% [markdown]
# solution to question 1: call the first 5 rows

# %%
covidata.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# solution to question 2 : we choose Argentina because it begins with "A" like "Amit"

# %%
my_country = covidata[covidata['location'].str.contains('Argentina')] 
my_country
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 403  Argentina      ARG  2020-12-29               700.0                NaN
# 404  Argentina      ARG  2020-12-30                 NaN                NaN
# 405  Argentina      ARG  2020-12-31             32013.0                NaN
# 406  Argentina      ARG  2021-01-01                 NaN                NaN
# 407  Argentina      ARG  2021-01-02                 NaN                NaN
# ..         ...      ...         ...                 ...                ...
# 498  Argentina      ARG  2021-04-03           4178896.0          3495125.0
# 499  Argentina      ARG  2021-04-04           4234505.0          3550166.0
# 500  Argentina      ARG  2021-04-05           4260808.0          3576423.0
# 501  Argentina      ARG  2021-04-06           4404175.0          3712009.0
# 502  Argentina      ARG  2021-04-07           4571819.0          3870734.0
#
# ...

# %% [markdown]
# solution to question 3 : the record number of Argentina

# %%
my_country.location.count()
# Out:
# 82

# %% [markdown]
# solution to question 4 : The day that most people vaccinated in Israel

# %%
row_name = my_country.daily_vaccinations.idxmax()
my_country.loc[row_name].date
# Out:
# '2021-03-17'

# %% [markdown]
# solution to question 5 : the first 3 records with country name, date and daily vaccinations

# %%
frows = my_country.head(3)
frows.loc[:,['location', 'date', 'daily_vaccinations']]
# Out:
#       location        date  daily_vaccinations
# 318  Argentina  2020-12-29                 NaN
# 319  Argentina  2020-12-30             15656.0
# 320  Argentina  2020-12-31             15656.0

# %% [markdown]
# solution to question 6 : The average number of vaccinators in Argentina is

# %%
my_country.daily_vaccinations.mean()
# Out:
# 33620.20987654321

# %% [markdown]
# solution to question 7 : delete the days without information

# %%
my_country[my_country.people_vaccinated_per_hundred.notnull()]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 340  Argentina      ARG  2021-01-20            247933.0           243539.0
# 341  Argentina      ARG  2021-01-21            265724.0           249372.0
# 342  Argentina      ARG  2021-01-22            279602.0           254456.0
# 343  Argentina      ARG  2021-01-23            288064.0           258876.0
# 344  Argentina      ARG  2021-01-24            292023.0           260036.0
# 345  Argentina      ARG  2021-01-25            292386.0           260122.0
# 346  Argentina      ARG  2021-01-26            305880.0           266969.0
# 347  Argentina      ARG  2021-01-27            318033.0           272323.0
# 348  Argentina      ARG  2021-01-28            327999.0           276548.0
# 349  Argentina      ARG  2021-01-29            344034.0           278451.0
# 350  Argentina      ARG  2021-01-30            366384.0           281023.0
# ...

# %% [markdown]
# solution to question 8 : To make an average we will take the variable without the empty values and do Harmonic average.

# %%
from scipy import stats
argenmean = (my_country["people_vaccinated_per_hundred"]).dropna()
stats.hmean(argenmean)
# Out:
# 1.0131183642047707

# %% [markdown]
# solution to question 9 : A loop that produces the largest value

# %%
median = my_country.daily_vaccinations.median()
mean = my_country.daily_vaccinations.mean()
if mean > median :
    print ("The largest of them is the mean and his value is", mean)
elif mean == median:
     print ("the mean and the median are the same and their value",mean)
    
else:
    print ("The largest of them is median and his value is", median)
# Out:
# The largest of them is the mean and his value is 26519.493333333332
