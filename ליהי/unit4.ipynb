# %% [markdown]
# # Unit 4 - Noisy data
# ---
# 1. [Histograms](#section1)
# 2. [Standard deviation](#section2)
# 3. [Boxplots](#section3)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ### 1. Histograms

# %% [markdown]
# #### Gym example
#
# Taken from: https://data36.com/plot-histogram-python-pandas/

# %%
mu = 168 #mean
sigma = 5 #stddev
sample = 250
np.random.seed(0)
height_f = np.random.normal(mu, sigma, sample).astype(int)

# %%
mu = 176 #mean
sigma = 6 #stddev
sample = 250
np.random.seed(1)
height_m = np.random.normal(mu, sigma, sample).astype(int)

# %%
gym = pd.DataFrame({'height_f': height_f, 'height_m': height_m})
gym.head(7)
# Out:
#    height_f  height_m
# 0       176       185
# 1       170       172
# 2       172       172
# 3       179       169
# 4       177       181
# 5       163       162
# 6       172       186

# %% [markdown]
# To begin with - why a histogram?
#
# This is what happens if we just plot lines:

# %%
gym.plot()

# %% [markdown]
# Ummm.. it's very messy.

# %% [markdown]
# #### Different histograms:

# %%
gym.hist('height_f')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024AE8B0F9D0>]],
#       dtype=object)

# %%
gym.hist(bins=5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024AE8B9F220>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024AE8BC9340>]],
#       dtype=object)

# %%
gym.plot.hist(bins=20)

# %%
gym.plot.hist(bins=20, alpha=0.7)

# %% [markdown]
# ---
# #### Back to our vaccinations data:

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
vacc_df = pd.read_csv(url) 
vacc_df.head(2)
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0

# %% [markdown]
# #### Look at data for different countries
# #### Use `groupby()` to group according to location

# %% [markdown]
# #### Attempt #1 - what is wrong?

# %%
vacc_df.groupby('location')[['total_vaccinations','daily_vaccinations','people_fully_vaccinated','people_fully_vaccinated_per_hundred']].max()
# Out:
#                    total_vaccinations  daily_vaccinations  \
# location
# Afghanistan              6.303050e+05             13921.0
# Africa                   3.801004e+07            950180.0
# Albania                  8.036820e+05             17565.0
# Algeria                  2.500000e+06             22664.0
# Andorra                  3.591600e+04              1182.0
# ...                               ...                 ...
# Wallis and Futuna        8.365000e+03               343.0
# World                    2.184594e+09          35849687.0
# Yemen                    1.040700e+05              4276.0
# Zambia                   1.471150e+05              5680.0
# Zimbabwe                 1.061951e+06             22863.0
#
#                    people_fully_vaccinated  \
# location
# Afghanistan                       148505.0
# Africa                           9463449.0
# Albania                           310336.0
# Algeria                                NaN
# Andorra                             8303.0
# ...                                    ...
# Wallis and Futuna                   3991.0
# World                          467035736.0
# Yemen                                  NaN
# Zambia                              5286.0
# Zimbabwe                          375315.0
#
#                    people_fully_vaccinated_per_hundred
# location
# Afghanistan                                       0.38
# Africa                                            0.71
# Albania                                          10.78
# Algeria                                            NaN
# Andorra                                          10.75
# ...                                                ...
# Wallis and Futuna                                35.49
# World                                             5.99
# Yemen                                              NaN
# Zambia                                            0.03
# Zimbabwe                                          2.53
#
# [227 rows x 4 columns]

# %% [markdown]
# #### Attempt #2
#
# #### Is this better?

# %%
vacc_df.fillna('0').groupby('location')[['total_vaccinations','daily_vaccinations','people_fully_vaccinated','people_fully_vaccinated_per_hundred']].max()
# Out:
#                    total_vaccinations  daily_vaccinations  \
# location
# Afghanistan                       NaN                 NaN
# Africa                            NaN                 NaN
# Albania                           NaN                 NaN
# Algeria                           NaN                 NaN
# Andorra                           NaN                 NaN
# ...                               ...                 ...
# Wallis and Futuna                 NaN                 NaN
# World                    2.184594e+09                 NaN
# Yemen                             NaN                 NaN
# Zambia                            NaN                 NaN
# Zimbabwe                          NaN                 NaN
#
#                   people_fully_vaccinated people_fully_vaccinated_per_hundred
# location
# Afghanistan                           NaN                                 NaN
# Africa                                NaN                                 NaN
# Albania                               NaN                                 NaN
# Algeria                                 0                                   0
# Andorra                               NaN                                 NaN
# ...                                   ...                                 ...
# Wallis and Futuna                     NaN                                 NaN
# World                                 NaN                                 NaN
# Yemen                                   0                                   0
# Zambia                                NaN                                 NaN
# Zimbabwe                              NaN                                 NaN
#
# [227 rows x 4 columns]

# %% [markdown]
# #### Attempt #3 - change the 0 from string to int, and finally, it works :-)

# %%
vacc_df.fillna(0).groupby('location')[['total_vaccinations','daily_vaccinations','people_fully_vaccinated','people_fully_vaccinated_per_hundred']].max()
# Out:
#                    total_vaccinations  daily_vaccinations  \
# location
# Afghanistan              6.303050e+05             13921.0
# Africa                   3.801004e+07            950180.0
# Albania                  8.036820e+05             17565.0
# Algeria                  2.500000e+06             22664.0
# Andorra                  3.591600e+04              1182.0
# ...                               ...                 ...
# Wallis and Futuna        8.365000e+03               343.0
# World                    2.184594e+09          35849687.0
# Yemen                    1.040700e+05              4276.0
# Zambia                   1.471150e+05              5680.0
# Zimbabwe                 1.061951e+06             22863.0
#
#                    people_fully_vaccinated  \
# location
# Afghanistan                       148505.0
# Africa                           9463449.0
# Albania                           310336.0
# Algeria                                0.0
# Andorra                             8303.0
# ...                                    ...
# Wallis and Futuna                   3991.0
# World                          467035736.0
# Yemen                                  0.0
# Zambia                              5286.0
# Zimbabwe                          375315.0
#
#                    people_fully_vaccinated_per_hundred
# location
# Afghanistan                                       0.38
# Africa                                            0.71
# Albania                                          10.78
# Algeria                                           0.00
# Andorra                                          10.75
# ...                                                ...
# Wallis and Futuna                                35.49
# World                                             5.99
# Yemen                                             0.00
# Zambia                                            0.03
# Zimbabwe                                          2.53
#
# [227 rows x 4 columns]

# %% [markdown]
# #### The `world` row shouldn't be there. Remove it using `.drop()` and `.index() :

# %%
vacc_df.drop(vacc_df.loc[vacc_df.location == 'World'].index, inplace = True)

# %% [markdown]
# ---
# #### Your turn:
# >What do you think `.index` does? Why is it there? How can you find out?
# ---

# %% [markdown]
# Before we continue, just assign this long row to a new dataframe, will be easier

# %%
grouped_df = vacc_df.fillna(0).groupby('location')[['total_vaccinations','daily_vaccinations','people_fully_vaccinated','people_fully_vaccinated_per_hundred']].max().copy()
grouped_df.tail()
# Out:
#                    total_vaccinations  daily_vaccinations  \
# location
# Wales                       3432723.0             33151.0
# Wallis and Futuna              8365.0               343.0
# Yemen                        104070.0              4276.0
# Zambia                       147115.0              5680.0
# Zimbabwe                    1061951.0             22863.0
#
#                    people_fully_vaccinated  \
# location
# Wales                            1249268.0
# Wallis and Futuna                   3991.0
# Yemen                                  0.0
# Zambia                              5286.0
# Zimbabwe                          375315.0
#
#                    people_fully_vaccinated_per_hundred
# location
# Wales                                            39.62
# Wallis and Futuna                                35.49
# Yemen                                             0.00
# Zambia                                            0.03
# Zimbabwe                                          2.53

# %% [markdown]
# #### sort the values using 'sort_values()`

# %%
grouped_df.sort_values('people_fully_vaccinated_per_hundred', ascending = False).head(10)
# Out:
#                   total_vaccinations  daily_vaccinations  \
# location
# Gibraltar                    77717.0              1068.0
# Seychelles                  136526.0              2401.0
# San Marino                   42962.0               725.0
# Cayman Islands               84856.0              1024.0
# Israel                    10602001.0            184944.0
# Saint Helena                  7892.0               165.0
# Bermuda                      71114.0               773.0
# Malta                       553814.0              7557.0
# Falkland Islands              4407.0               189.0
# Aruba                       117036.0              2679.0
#
#                   people_fully_vaccinated  people_fully_vaccinated_per_hundred
# location
# Gibraltar                         38619.0                               114.63
# Seychelles                        65873.0                                66.98
# San Marino                        21355.0                                62.92
# Cayman Islands                    39090.0                                59.48
# Israel                          5139005.0                                59.37
# Saint Helena                       3531.0                                58.16
# Bermuda                           33560.0                                53.89
# Malta                            235133.0                                53.25
# Falkland Islands                   1775.0                                50.96
# Aruba                             52852.0                                49.50

# %% [markdown]
# #### Histogram according to all values:

# %%
grouped_df.hist(bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024AE9B14970>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024AE8BD2CD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024AE9B0AB20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024AE991DD00>]],
#       dtype=object)

# %% [markdown]
# #### Histogram according to people_fully_vaccinated_per_hundred

# %%
grouped_df.hist('people_fully_vaccinated_per_hundred',bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024AE9C866A0>]],
#       dtype=object)

# %% [markdown]
# #### Remove rows with 0's
#
# Note that this is different than changing values to 0's

# %%
grouped_df.drop(grouped_df[grouped_df.people_fully_vaccinated_per_hundred == 0.0].index, inplace=True)
#grouped_df
grouped_df.hist('people_fully_vaccinated_per_hundred',bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024AE93A7F40>]],
#       dtype=object)

# %% [markdown]
# ---
# >#### Your turn:
# >
# >Do the same, but for another column
# ---

# %% [markdown]
# ---
# >### Functions covered in this unit:
# >
# > `std()` - standard deviation
# >
# > `.hist(data, num_bins)` - the data and the number of bins
# >
# > `.plot()` - simple line plot
# >
# > `.hist(data, num_bins, alpha)` - the data, the number of bins and the transparency (default is 10 bins, all data and not transparent)
# >
# > `.plot.hist()` - histograms on same chart
# >
# > `.drop()` - removes unwanted rows or columns
# >
# > `.index()` - index of the selected rows
# >
# > `sort_values()` - self explantory.. it just sorts values
# >
# ---

# %% [markdown]
# ### 2. Standard deviation

# %% [markdown]
# An small example showing that the more the data is spread, the higher the std:

# %%
df = pd.DataFrame({'height' : [161, 156, 172], 
                   'weight': [67, 65, 89],
                   'age': [20,20,20]})
df
# Out:
#    height  weight  age
# 0     161      67   20
# 1     156      65   20
# 2     172      89   20

# %%
df.mean()
# Out:
# height    163.000000
# weight     73.666667
# age        20.000000
# dtype: float64

# %%
df.std()
# Out:
# height     8.185353
# weight    13.316656
# age        0.000000
# dtype: float64

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ### 3. Boxplots

# %%
np.random.seed(2345)
df = pd.DataFrame(np.random.randn(20,4),
                  columns=['C1', 'C2', 'C3', 'C4'])
df.head()
# Out:
#          C1        C2        C3        C4
# 0 -0.951299  1.768772 -1.141827  0.710755
# 1  0.510951  1.149029 -0.538460 -0.736645
# 2 -0.075996  0.848818  0.649783 -0.571212
# 3 -0.914158 -0.123520  0.281634  0.795612
# 4  0.179394  1.202007  0.371815 -0.290084

# %%
boxplot = df.boxplot(column=['C1', 'C2', 'C3'])

# %%
grouped_df.boxplot('people_fully_vaccinated_per_hundred')

# %%
grouped_df.sort_values('people_fully_vaccinated_per_hundred')
# Out:
#                           total_vaccinations  daily_vaccinations  \
# location
# Central African Republic             18408.0               934.0
# Uganda                              706626.0             20209.0
# Lesotho                              36759.0               666.0
# Kenya                               983580.0             39237.0
# Niger                               159525.0              7465.0
# ...                                      ...                 ...
# Israel                            10602001.0            184944.0
# Cayman Islands                       84856.0              1024.0
# San Marino                           42962.0               725.0
# Seychelles                          136526.0              2401.0
# Gibraltar                            77717.0              1068.0
#
#                           people_fully_vaccinated  \
# location
# Central African Republic                    717.0
# Uganda                                     4129.0
# Lesotho                                     122.0
# Kenya                                      8181.0
# Niger                                      6943.0
# ...                                           ...
# Israel                                  5139005.0
# Cayman Islands                            39090.0
# San Marino                                21355.0
# Seychelles                                65873.0
# Gibraltar                                 38619.0
#
#                           people_fully_vaccinated_per_hundred
# location
# Central African Republic                                 0.01
# Uganda                                                   0.01
# Lesotho                                                  0.01
# Kenya                                                    0.02
# Niger                                                    0.03
# ...                                                       ...
# Israel                                                  59.37
# Cayman Islands                                          59.48
# San Marino                                              62.92
# Seychelles                                              66.98
# Gibraltar                                              114.63
#
# [192 rows x 4 columns]

# %% [markdown]
# This doesn't seem to fit
# https://ourworldindata.org/grapher/covid-vaccination-doses-per-capita
#
# Is this an error???
